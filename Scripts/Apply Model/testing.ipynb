# %% [markdown]
# # Testing
#
# Just a space to perform some testing on the models!

# %%
import mlflow
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot as plt

os.chdir('../Train Model/')

# %% [markdown]
# ## 1. Loading
#
# ### 1.1 Load Data

# %%
df = pd.read_parquet('../../Data/Validation/04. Buffalo County.parquet')

# %% [markdown]
# ### 1.2 Load Model

# %%
logged_model = 'runs:/2a311967a9c24f8a9734f629bf3690e5/model'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)

# # Predict on a Pandas DataFrame.
# loaded_model.predict(pd.DataFrame(data))

# %% [markdown]
# ## 2. Apply Model

# %%
# # Predict on a Pandas DataFrame.
predictions = loaded_model.predict(pd.DataFrame(df.drop('label',axis=1)))

# %%
plt.hist(predictions,bins=200)
plt.ylim(0, 200)
plt.show()
